# %%
import pandas as pd

# %%
df=pd.read_csv('shopping_trends.csv')

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df.columns
# Out:
# Index(['Customer ID', 'Age', 'Gender', 'Item Purchased', 'Category',
#        'Purchase Amount (USD)', 'Location', 'Size', 'Color', 'Season',
#        'Review Rating', 'Subscription Status', 'Payment Method',
#        'Shipping Type', 'Discount Applied', 'Promo Code Used',
#        'Previous Purchases', 'Preferred Payment Method',
#        'Frequency of Purchases'],
#       dtype='object')

# %%
list(df.columns)
# Out:
# ['Customer ID',
#  'Age',
#  'Gender',
#  'Item Purchased',
#  'Category',
#  'Purchase Amount (USD)',
#  'Location',
#  'Size',
#  'Color',
#  'Season',
#  'Review Rating',
#  'Subscription Status',
#  'Payment Method',
#  'Shipping Type',
#  'Discount Applied',
#  'Promo Code Used',
#  'Previous Purchases',
#  'Preferred Payment Method',
#  'Frequency of Purchases']

# %%
df.head()
# Out:
#    Customer ID  Age Gender Item Purchased  Category  Purchase Amount (USD)  \
# 0            1   55   Male         Blouse  Clothing                     53
# 1            2   19   Male        Sweater  Clothing                     64
# 2            3   50   Male          Jeans  Clothing                     73
# 3            4   21   Male        Sandals  Footwear                     90
# 4            5   45   Male         Blouse  Clothing                     49
#
#         Location Size      Color  Season  Review Rating Subscription Status  \
# 0       Kentucky    L       Gray  Winter            3.1                 Yes
# 1          Maine    L     Maroon  Winter            3.1                 Yes
# 2  Massachusetts    S     Maroon  Spring            3.1                 Yes
# 3   Rhode Island    M     Maroon  Spring            3.5                 Yes
# 4         Oregon    M  Turquoise  Spring            2.7                 Yes
#
# ...

# %%
df.tail()
# Out:
#       Customer ID  Age  Gender Item Purchased     Category  \
# 3895         3896   40  Female         Hoodie     Clothing
# 3896         3897   52  Female       Backpack  Accessories
# 3897         3898   46  Female           Belt  Accessories
# 3898         3899   44  Female          Shoes     Footwear
# 3899         3900   52  Female        Handbag  Accessories
#
#       Purchase Amount (USD)    Location Size      Color  Season  \
# 3895                     28    Virginia    L  Turquoise  Summer
# 3896                     49        Iowa    L      White  Spring
# 3897                     33  New Jersey    L      Green  Spring
# 3898                     77   Minnesota    S      Brown  Summer
# 3899                     81  California    M      Beige  Spring
#
#       Review Rating Subscription Status Payment Method   Shipping Type  \
# 3895            4.2                  No           Cash  2-Day Shipping
# 3896            4.5                  No         PayPal    Store Pickup
# ...

# %%
df.dtypes
# Out:
# Customer ID                   int64
# Age                           int64
# Gender                       object
# Item Purchased               object
# Category                     object
# Purchase Amount (USD)         int64
# Location                     object
# Size                         object
# Color                        object
# Season                       object
# Review Rating               float64
# Subscription Status          object
# Payment Method               object
# Shipping Type                object
# Discount Applied             object
# Promo Code Used              object
# Previous Purchases            int64
# Preferred Payment Method     object
# Frequency of Purchases       object
# dtype: object

# %%
df.columns
# Out:
# Index(['Customer ID', 'Age', 'Gender', 'Item Purchased', 'Category',
#        'Purchase Amount (USD)', 'Location', 'Size', 'Color', 'Season',
#        'Review Rating', 'Subscription Status', 'Payment Method',
#        'Shipping Type', 'Discount Applied', 'Promo Code Used',
#        'Previous Purchases', 'Preferred Payment Method',
#        'Frequency of Purchases'],
#       dtype='object')

# %%
df['Subscription Status']
# Out:
# 0       Yes
# 1       Yes
# 2       Yes
# 3       Yes
# 4       Yes
#        ...
# 3895     No
# 3896     No
# 3897     No
# 3898     No
# 3899     No
# Name: Subscription Status, Length: 3900, dtype: object

# %%
type(df['Subscription Status'])
# Out:
# pandas.core.series.Series

# %%
list(df['Subscription Status'])
# Out:
# ['Yes',
#  'Yes',
#  'Yes',
#  'Yes',
#  'Yes',
#  'Yes',
#  'Yes',
#  'Yes',
#  'Yes',
#  'Yes',
#  'Yes',
#  'Yes',
#  'Yes',
#  'Yes',
#  'Yes',
#  'Yes',
#  'Yes',
#  'Yes',
#  'Yes',
#  'Yes',
#  'Yes',
#  'Yes',
#  'Yes',
#  'Yes',
#  'Yes',
#  'Yes',
#  'Yes',
#  'Yes',
#  'Yes',
#  'Yes',
#  'Yes',
#  'Yes',
#  'Yes',
#  'Yes',
#  'Yes',
#  'Yes',
#  'Yes',
#  'Yes',
#  'Yes',
#  'Yes',
#  'Yes',
#  'Yes',
#  'Yes',
#  'Yes',
#  'Yes',
#  'Yes',
#  'Yes',
#  'Yes',
#  'Yes',
#  'Yes',
#  'Yes',
#  'Yes',
#  'Yes',
#  'Yes',
#  'Yes',
#  'Yes',
#  'Yes',
#  'Yes',
#  'Yes',
#  'Yes',
#  'Yes',
#  'Yes',
#  'Yes',
#  'Yes',
#  'Yes',
#  'Yes',
#  'Yes',
#  'Yes',
#  'Yes',
#  'Yes',
#  'Yes',
#  'Yes',
#  'Yes',
#  'Yes',
#  'Yes',
#  'Yes',
#  'Yes',
#  'Yes',
#  'Yes',
#  'Yes',
#  'Yes',
#  'Yes',
#  'Yes',
#  'Yes',
#  'Yes',
#  'Yes',
#  'Yes',
#  'Yes',
#  'Yes',
#  'Yes',
#  'Yes',
#  'Yes',
#  'Yes',
#  'Yes',
#  'Yes',
#  'Yes',
#  'Yes',
#  'Yes',
#  'Yes',
#  'Yes',
# ...

# %%
df[['Subscription Status']]
# Out:
#      Subscription Status
# 0                    Yes
# 1                    Yes
# 2                    Yes
# 3                    Yes
# 4                    Yes
# ...                  ...
# 3895                  No
# 3896                  No
# 3897                  No
# 3898                  No
# 3899                  No
#
# [3900 rows x 1 columns]

# %%
type(df[['Subscription Status']])
# Out:
# pandas.core.frame.DataFrame

# %%
df.columns
# Out:
# Index(['Customer ID', 'Age', 'Gender', 'Item Purchased', 'Category',
#        'Purchase Amount (USD)', 'Location', 'Size', 'Color', 'Season',
#        'Review Rating', 'Subscription Status', 'Payment Method',
#        'Shipping Type', 'Discount Applied', 'Promo Code Used',
#        'Previous Purchases', 'Preferred Payment Method',
#        'Frequency of Purchases'],
#       dtype='object')

# %%
df[['Purchase Amount (USD)','Payment Method']]
# Out:
#       Purchase Amount (USD) Payment Method
# 0                        53    Credit Card
# 1                        64  Bank Transfer
# 2                        73           Cash
# 3                        90         PayPal
# 4                        49           Cash
# ...                     ...            ...
# 3895                     28           Cash
# 3896                     49         PayPal
# 3897                     33    Credit Card
# 3898                     77         PayPal
# 3899                     81  Bank Transfer
#
# [3900 rows x 2 columns]

# %%
df1=pd.read_csv('https://raw.githubusercontent.com/pandas-dev/pandas/master/doc/data/titanic.csv')

# %%
type(df1)
# Out:
# pandas.core.frame.DataFrame

# %%
df1.dtypes
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %%
df.head()
# Out:
#    Customer ID  Age Gender Item Purchased  Category  Purchase Amount (USD)  \
# 0            1   55   Male         Blouse  Clothing                     53
# 1            2   19   Male        Sweater  Clothing                     64
# 2            3   50   Male          Jeans  Clothing                     73
# 3            4   21   Male        Sandals  Footwear                     90
# 4            5   45   Male         Blouse  Clothing                     49
#
#         Location Size      Color  Season  Review Rating Subscription Status  \
# 0       Kentucky    L       Gray  Winter            3.1                 Yes
# 1          Maine    L     Maroon  Winter            3.1                 Yes
# 2  Massachusetts    S     Maroon  Spring            3.1                 Yes
# 3   Rhode Island    M     Maroon  Spring            3.5                 Yes
# 4         Oregon    M  Turquoise  Spring            2.7                 Yes
#
# ...

# %%
df.tail()
# Out:
#       Customer ID  Age  Gender Item Purchased     Category  \
# 3895         3896   40  Female         Hoodie     Clothing
# 3896         3897   52  Female       Backpack  Accessories
# 3897         3898   46  Female           Belt  Accessories
# 3898         3899   44  Female          Shoes     Footwear
# 3899         3900   52  Female        Handbag  Accessories
#
#       Purchase Amount (USD)    Location Size      Color  Season  \
# 3895                     28    Virginia    L  Turquoise  Summer
# 3896                     49        Iowa    L      White  Spring
# 3897                     33  New Jersey    L      Green  Spring
# 3898                     77   Minnesota    S      Brown  Summer
# 3899                     81  California    M      Beige  Spring
#
#       Review Rating Subscription Status Payment Method   Shipping Type  \
# 3895            4.2                  No           Cash  2-Day Shipping
# 3896            4.5                  No         PayPal    Store Pickup
# ...

# %%
df1.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
df1[['Pclass']]
# Out:
#      Pclass
# 0         3
# 1         1
# 2         3
# 3         1
# 4         3
# ..      ...
# 886       2
# 887       1
# 888       3
# 889       1
# 890       3
#
# [891 rows x 1 columns]

# %%
df1.to_csv("titanic_data.csv")

# %%
pip install lxml
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.0/8.0 MB 55.9 MB/s eta 0:00:0000:0100:01
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import lxml
import pandas as pd
url_data=pd.read_html("https://www.basketball-reference.com/leagues/NBA_2022.html")

# %%
type(url_data)
# Out:
# list

# %%
len(url_data)
# Out:
# 13

# %%
df2=url_data[0]

# %%
df2.head()
# Out:
#     Eastern Conference   W   L   W/L%   GB   PS/G   PA/G   SRS
# 0          Miami Heat*  53  29  0.646    —  110.0  105.6  4.23
# 1      Boston Celtics*  51  31  0.622  2.0  111.8  104.5  7.02
# 2     Milwaukee Bucks*  51  31  0.622  2.0  115.5  112.1  3.22
# 3  Philadelphia 76ers*  51  31  0.622  2.0  109.9  107.3  2.57
# 4     Toronto Raptors*  48  34  0.585  5.0  109.4  107.1  2.38

# %%
df2.tail()
# Out:
#     Eastern Conference   W   L   W/L%    GB   PS/G   PA/G   SRS
# 10     New York Knicks  37  45  0.451  16.0  106.5  106.6 -0.01
# 11  Washington Wizards  35  47  0.427  18.0  108.6  112.0 -3.23
# 12      Indiana Pacers  25  57  0.305  28.0  111.5  114.9 -3.26
# 13     Detroit Pistons  23  59  0.280  30.0  104.8  112.5 -7.36
# 14       Orlando Magic  22  60  0.268  31.0  104.2  112.2 -7.67

# %%
df2.dtypes
# Out:
# Eastern Conference     object
# W                       int64
# L                       int64
# W/L%                  float64
# GB                     object
# PS/G                  float64
# PA/G                  float64
# SRS                   float64
# dtype: object

# %%
df2.columns
# Out:
# Index(['Eastern Conference', 'W', 'L', 'W/L%', 'GB', 'PS/G', 'PA/G', 'SRS'], dtype='object')

# %%
df2['W']
# Out:
# 0     53
# 1     51
# 2     51
# 3     51
# 4     48
# 5     46
# 6     44
# 7     44
# 8     43
# 9     43
# 10    37
# 11    35
# 12    25
# 13    23
# 14    22
# Name: W, dtype: int64

# %%
df2.to_csv("player.csv")
