# %%
import pandas as pd

# %%
df=pd.read_csv("tinanic_data.csv")

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age',
#        'SibSp', 'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
df['Name']
# Out:
# 0                                Braund, Mr. Owen Harris
# 1      Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2                                 Heikkinen, Miss. Laina
# 3           Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4                               Allen, Mr. William Henry
#                              ...
# 886                                Montvila, Rev. Juozas
# 887                         Graham, Miss. Margaret Edith
# 888             Johnston, Miss. Catherine Helen "Carrie"
# 889                                Behr, Mr. Karl Howell
# 890                                  Dooley, Mr. Patrick
# Name: Name, Length: 891, dtype: object

# %%
df['Name'][2:11]
# Out:
# 2                                Heikkinen, Miss. Laina
# 3          Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4                              Allen, Mr. William Henry
# 5                                      Moran, Mr. James
# 6                               McCarthy, Mr. Timothy J
# 7                        Palsson, Master. Gosta Leonard
# 8     Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)
# 9                   Nasser, Mrs. Nicholas (Adele Achem)
# 10                      Sandstrom, Miss. Marguerite Rut
# Name: Name, dtype: object

# %%
type(df['Name'])
# Out:
# pandas.core.series.Series

# %%
len(df)
# Out:
# 891

# %%
l=['a','b','c','d','e','f']

# %%
pd.Series(l)
# Out:
# 0    a
# 1    b
# 2    c
# 3    d
# 4    e
# 5    f
# dtype: object

# %%
list(df['Name'])
# Out:
# ['Braund, Mr. Owen Harris',
#  'Cumings, Mrs. John Bradley (Florence Briggs Thayer)',
#  'Heikkinen, Miss. Laina',
#  'Futrelle, Mrs. Jacques Heath (Lily May Peel)',
#  'Allen, Mr. William Henry',
#  'Moran, Mr. James',
#  'McCarthy, Mr. Timothy J',
#  'Palsson, Master. Gosta Leonard',
#  'Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)',
#  'Nasser, Mrs. Nicholas (Adele Achem)',
#  'Sandstrom, Miss. Marguerite Rut',
#  'Bonnell, Miss. Elizabeth',
#  'Saundercock, Mr. William Henry',
#  'Andersson, Mr. Anders Johan',
#  'Vestrom, Miss. Hulda Amanda Adolfina',
#  'Hewlett, Mrs. (Mary D Kingcome) ',
#  'Rice, Master. Eugene',
#  'Williams, Mr. Charles Eugene',
#  'Vander Planke, Mrs. Julius (Emelia Maria Vandemoortele)',
#  'Masselmani, Mrs. Fatima',
#  'Fynney, Mr. Joseph J',
#  'Beesley, Mr. Lawrence',
#  'McGowan, Miss. Anna "Annie"',
#  'Sloper, Mr. William Thompson',
#  'Palsson, Miss. Torborg Danira',
#  'Asplund, Mrs. Carl Oscar (Selma Augusta Emilia Johansson)',
# ...

# %%
df['Name'][2:7]
# Out:
# 2                          Heikkinen, Miss. Laina
# 3    Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4                        Allen, Mr. William Henry
# 5                                Moran, Mr. James
# 6                         McCarthy, Mr. Timothy J
# Name: Name, dtype: object

# %%
s1=pd.Series(df['Name'][2:7],index=['a','b','c','d0','e'])

# %%
s=df['Name'][2:7]

# %%
s2=s.append(s1)
# Out:
# /tmp/ipykernel_77/2474463794.py:1: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   s2=s.append(s1)

# %%
s+s1
# Out:
# 2     NaN
# 3     NaN
# 4     NaN
# 5     NaN
# 6     NaN
# a     NaN
# b     NaN
# c     NaN
# d0    NaN
# e     NaN
# Name: Name, dtype: object

# %%
s2*2
# Out:
# 2          Heikkinen, Miss. LainaHeikkinen, Miss. Laina
# 3     Futrelle, Mrs. Jacques Heath (Lily May Peel)Fu...
# 4      Allen, Mr. William HenryAllen, Mr. William Henry
# 5                      Moran, Mr. JamesMoran, Mr. James
# 6        McCarthy, Mr. Timothy JMcCarthy, Mr. Timothy J
# a                                                   NaN
# b                                                   NaN
# c                                                   NaN
# d0                                                  NaN
# e                                                   NaN
# Name: Name, dtype: object

# %%
df.head(3)
# Out:
#    Unnamed: 0  PassengerId  Survived  Pclass  \
# 0           0            1         0       3
# 1           1            2         1       1
# 2           2            3         1       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S

# %%
df
# Out:
#      Unnamed: 0  PassengerId  Survived  Pclass  \
# 0             0            1         0       3
# 1             1            2         1       1
# 2             2            3         1       3
# 3             3            4         1       1
# 4             4            5         0       3
# ..          ...          ...       ...     ...
# 886         886          887         0       2
# 887         887          888         1       1
# 888         888          889         0       3
# 889         889          890         1       1
# 890         890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# ...

# %%
df
# Out:
#      Unnamed: 0  PassengerId  Survived  Pclass  \
# 0             0            1         0       3
# 1             1            2         1       1
# 2             2            3         1       3
# 3             3            4         1       1
# 4             4            5         0       3
# ..          ...          ...       ...     ...
# 886         886          887         0       2
# 887         887          888         1       1
# 888         888          889         0       3
# 889         889          890         1       1
# 890         890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# ...

# %%
df.drop('Pclass',axis=1,inplace=True)

# %%
df.head()
# Out:
#    Unnamed: 0  PassengerId  Survived  \
# 0           0            1         0
# 1           1            2         1
# 2           2            3         1
# 3           3            4         1
# 4           4            5         0
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# ...

# %%
df.drop(3,inplace=True)

# %%
df.head()
# Out:
#    Unnamed: 0  PassengerId  Survived  \
# 0           0            1         0
# 1           1            2         1
# 2           2            3         1
# 4           4            5         0
# 5           5            6         0
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 4                           Allen, Mr. William Henry    male  35.0      0
# 5                                   Moran, Mr. James    male   NaN      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 4      0            373450   8.0500   NaN        S
# ...

# %%
df.set_index('Name',inplace=True)

# %%
df.head()
# Out:
#                                                     Unnamed: 0  PassengerId  \
# Name
# Braund, Mr. Owen Harris                                      0            1
# Cumings, Mrs. John Bradley (Florence Briggs Tha...           1            2
# Heikkinen, Miss. Laina                                       2            3
# Allen, Mr. William Henry                                     4            5
# Moran, Mr. James                                             5            6
#
#                                                     Survived     Sex   Age  \
# Name
# Braund, Mr. Owen Harris                                    0    male  22.0
# Cumings, Mrs. John Bradley (Florence Briggs Tha...         1  female  38.0
# Heikkinen, Miss. Laina                                     1  female  26.0
# Allen, Mr. William Henry                                   0    male  35.0
# Moran, Mr. James                                           0    male   NaN
#
# ...

# %%
df.loc['Cumings, Mrs. John Bradley (Florence Briggs Thayer)']
# Out:
# Unnamed: 0            1
# PassengerId           2
# Survived              1
# Sex              female
# Age                38.0
# SibSp                 1
# Parch                 0
# Ticket         PC 17599
# Fare            71.2833
# Cabin               C85
# Embarked              C
# Name: Cumings, Mrs. John Bradley (Florence Briggs Thayer), dtype: object

# %%
df.iloc[0:4]
# Out:
#                                                     Unnamed: 0  PassengerId  \
# Name
# Braund, Mr. Owen Harris                                      0            1
# Cumings, Mrs. John Bradley (Florence Briggs Tha...           1            2
# Heikkinen, Miss. Laina                                       2            3
# Allen, Mr. William Henry                                     4            5
#
#                                                     Survived     Sex   Age  \
# Name
# Braund, Mr. Owen Harris                                    0    male  22.0
# Cumings, Mrs. John Bradley (Florence Briggs Tha...         1  female  38.0
# Heikkinen, Miss. Laina                                     1  female  26.0
# Allen, Mr. William Henry                                   0    male  35.0
#
#                                                     SibSp  Parch  \
# Name
# Braund, Mr. Owen Harris                                 1      0
# ...

# %%
df.reset_index(inplace=True)

# %%
df.head(3)
# Out:
#                                                 Name  Unnamed: 0  PassengerId  \
# 0                            Braund, Mr. Owen Harris           0            1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...           1            2
# 2                             Heikkinen, Miss. Laina           2            3
#
#    Survived     Sex   Age  SibSp  Parch            Ticket     Fare Cabin  \
# 0         0    male  22.0      1      0         A/5 21171   7.2500   NaN
# 1         1  female  38.0      1      0          PC 17599  71.2833   C85
# 2         1  female  26.0      0      0  STON/O2. 3101282   7.9250   NaN
#
#   Embarked
# 0        S
# 1        C
# 2        S

# %%
d={"key1":[2,3,4,5],
   "key2":[6,7,8,9],
   "key3":[10,11,12,13]}

# %%
d2=pd.DataFrame(d)

# %%
df1=pd.read_csv("player.csv")

# %%
df1
# Out:
#     Unnamed: 0   Eastern Conference   W   L   W/L%    GB   PS/G   PA/G   SRS
# 0            0          Miami Heat*  53  29  0.646     —  110.0  105.6  4.23
# 1            1      Boston Celtics*  51  31  0.622   2.0  111.8  104.5  7.02
# 2            2     Milwaukee Bucks*  51  31  0.622   2.0  115.5  112.1  3.22
# 3            3  Philadelphia 76ers*  51  31  0.622   2.0  109.9  107.3  2.57
# 4            4     Toronto Raptors*  48  34  0.585   5.0  109.4  107.1  2.38
# 5            5       Chicago Bulls*  46  36  0.561   7.0  111.6  112.0 -0.38
# 6            6       Brooklyn Nets*  44  38  0.537   9.0  112.9  112.1  0.82
# 7            7  Cleveland Cavaliers  44  38  0.537   9.0  107.8  105.7  2.04
# 8            8       Atlanta Hawks*  43  39  0.524  10.0  113.9  112.4  1.55
# 9            9    Charlotte Hornets  43  39  0.524  10.0  115.3  114.9  0.53
# 10          10      New York Knicks  37  45  0.451  16.0  106.5  106.6 -0.01
# ...

# %%
df1.dropna()
# Out:
#     Unnamed: 0   Eastern Conference   W   L   W/L%    GB   PS/G   PA/G   SRS
# 0            0          Miami Heat*  53  29  0.646     —  110.0  105.6  4.23
# 1            1      Boston Celtics*  51  31  0.622   2.0  111.8  104.5  7.02
# 2            2     Milwaukee Bucks*  51  31  0.622   2.0  115.5  112.1  3.22
# 3            3  Philadelphia 76ers*  51  31  0.622   2.0  109.9  107.3  2.57
# 4            4     Toronto Raptors*  48  34  0.585   5.0  109.4  107.1  2.38
# 5            5       Chicago Bulls*  46  36  0.561   7.0  111.6  112.0 -0.38
# 6            6       Brooklyn Nets*  44  38  0.537   9.0  112.9  112.1  0.82
# 7            7  Cleveland Cavaliers  44  38  0.537   9.0  107.8  105.7  2.04
# 8            8       Atlanta Hawks*  43  39  0.524  10.0  113.9  112.4  1.55
# 9            9    Charlotte Hornets  43  39  0.524  10.0  115.3  114.9  0.53
# 10          10      New York Knicks  37  45  0.451  16.0  106.5  106.6 -0.01
# ...

# %%
df.head()
# Out:
#                                                 Name  Unnamed: 0  PassengerId  \
# 0                            Braund, Mr. Owen Harris           0            1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...           1            2
# 2                             Heikkinen, Miss. Laina           2            3
# 3                           Allen, Mr. William Henry           4            5
# 4                                   Moran, Mr. James           5            6
#
#    Survived     Sex   Age  SibSp  Parch            Ticket     Fare Cabin  \
# 0         0    male  22.0      1      0         A/5 21171   7.2500   NaN
# 1         1  female  38.0      1      0          PC 17599  71.2833   C85
# 2         1  female  26.0      0      0  STON/O2. 3101282   7.9250   NaN
# 3         0    male  35.0      0      0            373450   8.0500   NaN
# 4         0    male   NaN      0      0            330877   8.4583   NaN
#
#   Embarked
# 0        S
# 1        C
# 2        S
# ...

# %%
df.groupby('Survived').mean()
# Out:
# /tmp/ipykernel_77/1397368861.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df.groupby('Survived').mean()
#           Unnamed: 0  PassengerId        Age     SibSp     Parch       Fare
# Survived
# 0         446.016393   447.016393  30.626179  0.553734  0.329690  22.117887
# 1         444.659824   445.659824  28.320657  0.472141  0.466276  48.381611

# %%
df.groupby('Survived').sum()
# Out:
# /tmp/ipykernel_77/351563020.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df.groupby('Survived').sum()
#           Unnamed: 0  PassengerId       Age  SibSp  Parch        Fare
# Survived
# 0             244863       245412  12985.50    304    181  12142.7199
# 1             151629       151970   8184.67    161    159  16498.1294

# %%
df.head(2)
# Out:
#                                                 Name  Unnamed: 0  PassengerId  \
# 0                            Braund, Mr. Owen Harris           0            1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...           1            2
#
#    Survived     Sex   Age  SibSp  Parch     Ticket     Fare Cabin Embarked
# 0         0    male  22.0      1      0  A/5 21171   7.2500   NaN        S
# 1         1  female  38.0      1      0   PC 17599  71.2833   C85        C

# %%
df.groupby('Sex').sum()['Fare']
# Out:
# /tmp/ipykernel_77/1272871990.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df.groupby('Sex').sum()['Fare']
# Sex
# female    13913.5628
# male      14727.2865
# Name: Fare, dtype: float64

# %%
df.groupby('Survived').mean()['Age']
# Out:
# /tmp/ipykernel_77/3987497164.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df.groupby('Survived').mean()['Age']
# Survived
# 0    30.626179
# 1    28.320657
# Name: Age, dtype: float64

# %%
df.groupby('Parch').mean()['Fare']
# Out:
# /tmp/ipykernel_77/497860158.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df.groupby('Parch').mean()['Fare']
# Parch
# 0    25.546134
# 1    46.778180
# 2    64.337604
# 3    25.951660
# 4    84.968750
# 5    32.550000
# 6    46.900000
# Name: Fare, dtype: float64

# %%
df.groupby('Parch').sum()
# Out:
# /tmp/ipykernel_77/3030151418.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df.groupby('Parch').sum()
#        Unnamed: 0  PassengerId  Survived       Age  SibSp        Fare
# Parch
# 0          301202       301879       232  16730.00    160  17294.7325
# 1           54765        54883        65   2686.42    128   5519.8252
# 2           33253        33333        40   1170.75    165   5147.0083
# 3            2891         2896         3    166.00      5    129.7583
# 4            1532         1536         0    178.00      3    339.8750
# 5            2171         2176         1    196.00      3    162.7500
# 6             678          679         0     43.00      1     46.9000

# %%
df3=df.groupby('Parch').sum()
# Out:
# /tmp/ipykernel_77/2212392021.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df3=df.groupby('Parch').sum()

# %%
df3.T
# Out:
# Parch                  0           1           2          3         4  \
# Unnamed: 0   301202.0000  54765.0000  33253.0000  2891.0000  1532.000
# PassengerId  301879.0000  54883.0000  33333.0000  2896.0000  1536.000
# Survived        232.0000     65.0000     40.0000     3.0000     0.000
# Age           16730.0000   2686.4200   1170.7500   166.0000   178.000
# SibSp           160.0000    128.0000    165.0000     5.0000     3.000
# Fare          17294.7325   5519.8252   5147.0083   129.7583   339.875
#
# Parch              5      6
# Unnamed: 0   2171.00  678.0
# PassengerId  2176.00  679.0
# Survived        1.00    0.0
# Age           196.00   43.0
# SibSp           3.00    1.0
# Fare          162.75   46.9

# %%
df.head(2)
# Out:
#                                                 Name  Unnamed: 0  PassengerId  \
# 0                            Braund, Mr. Owen Harris           0            1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...           1            2
#
#    Survived     Sex   Age  SibSp  Parch     Ticket     Fare Cabin Embarked
# 0         0    male  22.0      1      0  A/5 21171   7.2500   NaN        S
# 1         1  female  38.0      1      0   PC 17599  71.2833   C85        C

# %%
df11=df[['Name','PassengerId',	'Survived',	'Sex','Age']]	[0:5]

# %%
df11
# Out:
#                                                 Name  PassengerId  Survived  \
# 0                            Braund, Mr. Owen Harris            1         0
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...            2         1
# 2                             Heikkinen, Miss. Laina            3         1
# 3                           Allen, Mr. William Henry            5         0
# 4                                   Moran, Mr. James            6         0
#
#       Sex   Age
# 0    male  22.0
# 1  female  38.0
# 2  female  26.0
# 3    male  35.0
# 4    male   NaN

# %%
df12=df[['Name','PassengerId',	'Survived',	'Sex','Age']]	[5:11]

# %%
df12
# Out:
#                                                  Name  PassengerId  Survived  \
# 5                             McCarthy, Mr. Timothy J            7         0
# 6                      Palsson, Master. Gosta Leonard            8         0
# 7   Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)            9         1
# 8                 Nasser, Mrs. Nicholas (Adele Achem)           10         1
# 9                     Sandstrom, Miss. Marguerite Rut           11         1
# 10                           Bonnell, Miss. Elizabeth           12         1
#
#        Sex   Age
# 5     male  54.0
# 6     male   2.0
# 7   female  27.0
# 8   female  14.0
# 9   female   4.0
# 10  female  58.0

# %%
pd.concat([df11,df12])
# Out:
#                                                  Name  PassengerId  Survived  \
# 0                             Braund, Mr. Owen Harris            1         0
# 1   Cumings, Mrs. John Bradley (Florence Briggs Th...            2         1
# 2                              Heikkinen, Miss. Laina            3         1
# 3                            Allen, Mr. William Henry            5         0
# 4                                    Moran, Mr. James            6         0
# 5                             McCarthy, Mr. Timothy J            7         0
# 6                      Palsson, Master. Gosta Leonard            8         0
# 7   Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)            9         1
# 8                 Nasser, Mrs. Nicholas (Adele Achem)           10         1
# 9                     Sandstrom, Miss. Marguerite Rut           11         1
# 10                           Bonnell, Miss. Elizabeth           12         1
#
#        Sex   Age
# 0     male  22.0
# ...

# %%
df5=pd.concat([df11,df12],axis=1)

# %%
df5.fillna("himu")
# Out:
#                                                  Name PassengerId Survived  \
# 0                             Braund, Mr. Owen Harris         1.0      0.0
# 1   Cumings, Mrs. John Bradley (Florence Briggs Th...         2.0      1.0
# 2                              Heikkinen, Miss. Laina         3.0      1.0
# 3                            Allen, Mr. William Henry         5.0      0.0
# 4                                    Moran, Mr. James         6.0      0.0
# 5                                                himu        himu     himu
# 6                                                himu        himu     himu
# 7                                                himu        himu     himu
# 8                                                himu        himu     himu
# 9                                                himu        himu     himu
# 10                                               himu        himu     himu
#
# ...

# %%
d1=pd.DataFrame({"key1":[2,3,4,5],
   "key2":[6,7,8,9],
   "key3":[10,11,12,13]})

# %%
d1
# Out:
#    key1  key2  key3
# 0     2     6    10
# 1     3     7    11
# 2     4     8    12
# 3     5     9    13

# %%
d2=pd.DataFrame({"key1":[1,2,3,4],
   "key2":[5,6,7,8],
   "key2":[13,15,29,52]})

# %%
d2
# Out:
#    key1  key2
# 0     1    13
# 1     2    15
# 2     3    29
# 3     4    52

# %%
pd.merge(d1,d2)
# Out:
# Empty DataFrame
# Columns: [key1, key2, key3]
# Index: []

# %%
pd.merge(d1,d2,how='right')
# Out:
#    key1  key2  key3
# 0     1    13   NaN
# 1     2    15   NaN
# 2     3    29   NaN
# 3     4    52   NaN

# %%
pd.merge(d1,d2,how='left')
# Out:
#    key1  key2  key3
# 0     2     6    10
# 1     3     7    11
# 2     4     8    12
# 3     5     9    13

# %%
pd.merge(d1,d2,how='outer')
# Out:
#    key1  key2  key3
# 0     2     6  10.0
# 1     3     7  11.0
# 2     4     8  12.0
# 3     5     9  13.0
# 4     1    13   NaN
# 5     2    15   NaN
# 6     3    29   NaN
# 7     4    52   NaN

# %%
d1
# Out:
#    key1  key2  key3
# 0     2     6    10
# 1     3     7    11
# 2     4     8    12
# 3     5     9    13

# %%
d2
# Out:
#    key1  key2
# 0     1    13
# 1     2    15
# 2     3    29
# 3     4    52

# %%
d1
# Out:
#    key1  key2  key3
# 0     2     6    10
# 1     3     7    11
# 2     4     8    12
# 3     5     9    13

# %%
d2
# Out:
#    key1  key2
# 0     1    13
# 1     2    15
# 2     3    29
# 3     4    52

# %%
pd.merge(d1,d2,how='left',left_on='key1',right_on='key2')
# Out:
#    key1_x  key2_x  key3  key1_y  key2_y
# 0       2       6    10     NaN     NaN
# 1       3       7    11     NaN     NaN
# 2       4       8    12     NaN     NaN
# 3       5       9    13     NaN     NaN

# %%
d2=pd.DataFrame({"key11":[1,2,3,4],
                 "key12":[5,6,7,8],
                 "key13":[13,15,29,52]},
                 index=['a','b','c','d']
                 )

# %%
d1=pd.DataFrame({"key1":[2,3,4,5],
   "key2":[6,7,8,9],
   "key3":[10,11,12,13]},
    index=['h','i','j','a']
               )

# %%
d1
# Out:
#    key1  key2  key3
# h     2     6    10
# i     3     7    11
# j     4     8    12
# a     5     9    13

# %%
d2
# Out:
#    key11  key12  key13
# a      1      5     13
# b      2      6     15
# c      3      7     29
# d      4      8     52

# %%
d1.join(d2)
# Out:
#    key1  key2  key3  key11  key12  key13
# h     2     6    10    NaN    NaN    NaN
# i     3     7    11    NaN    NaN    NaN
# j     4     8    12    NaN    NaN    NaN
# a     5     9    13    1.0    5.0   13.0

# %%
d1.join(d2,how='inner')
# Out:
#    key1  key2  key3  key11  key12  key13
# a     5     9    13      1      5     13

# %%
d1.join(d2,how='outer')
# Out:
#    key1  key2  key3  key11  key12  key13
# a   5.0   9.0  13.0    1.0    5.0   13.0
# b   NaN   NaN   NaN    2.0    6.0   15.0
# c   NaN   NaN   NaN    3.0    7.0   29.0
# d   NaN   NaN   NaN    4.0    8.0   52.0
# h   2.0   6.0  10.0    NaN    NaN    NaN
# i   3.0   7.0  11.0    NaN    NaN    NaN
# j   4.0   8.0  12.0    NaN    NaN    NaN

# %%
d1.join(d2,how='cross')
# Out:
#     key1  key2  key3  key11  key12  key13
# 0      2     6    10      1      5     13
# 1      2     6    10      2      6     15
# 2      2     6    10      3      7     29
# 3      2     6    10      4      8     52
# 4      3     7    11      1      5     13
# 5      3     7    11      2      6     15
# 6      3     7    11      3      7     29
# 7      3     7    11      4      8     52
# 8      4     8    12      1      5     13
# 9      4     8    12      2      6     15
# 10     4     8    12      3      7     29
# 11     4     8    12      4      8     52
# 12     5     9    13      1      5     13
# 13     5     9    13      2      6     15
# 14     5     9    13      3      7     29
# 15     5     9    13      4      8     52

# %%
df.head(2)
# Out:
#                                                 Name  Unnamed: 0  PassengerId  \
# 0                            Braund, Mr. Owen Harris           0            1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...           1            2
#
#    Survived     Sex   Age  SibSp  Parch     Ticket     Fare Cabin Embarked
# 0         0    male  22.0      1      0  A/5 21171   7.2500   NaN        S
# 1         1  female  38.0      1      0   PC 17599  71.2833   C85        C

# %%
df['Fare_inr']=df['Fare'].apply(lambda x: x*80)

# %%
df.head()
# Out:
#                                                 Name  Unnamed: 0  PassengerId  \
# 0                            Braund, Mr. Owen Harris           0            1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...           1            2
# 2                             Heikkinen, Miss. Laina           2            3
# 3                           Allen, Mr. William Henry           4            5
# 4                                   Moran, Mr. James           5            6
#
#    Survived     Sex   Age  SibSp  Parch            Ticket     Fare Cabin  \
# 0         0    male  22.0      1      0         A/5 21171   7.2500   NaN
# 1         1  female  38.0      1      0          PC 17599  71.2833   C85
# 2         1  female  26.0      0      0  STON/O2. 3101282   7.9250   NaN
# 3         0    male  35.0      0      0            373450   8.0500   NaN
# 4         0    male   NaN      0      0            330877   8.4583   NaN
#
#   Embarked  Fare_inr
# 0        S   580.000
# ...

# %%
df['len_name']=df['Name'].apply(len)

# %%
df.head()
# Out:
#                                                 Name  Unnamed: 0  PassengerId  \
# 0                            Braund, Mr. Owen Harris           0            1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...           1            2
# 2                             Heikkinen, Miss. Laina           2            3
# 3                           Allen, Mr. William Henry           4            5
# 4                                   Moran, Mr. James           5            6
#
#    Survived     Sex   Age  SibSp  Parch            Ticket     Fare Cabin  \
# 0         0    male  22.0      1      0         A/5 21171   7.2500   NaN
# 1         1  female  38.0      1      0          PC 17599  71.2833   C85
# 2         1  female  26.0      0      0  STON/O2. 3101282   7.9250   NaN
# 3         0    male  35.0      0      0            373450   8.0500   NaN
# 4         0    male   NaN      0      0            330877   8.4583   NaN
#
#   Embarked  Fare_inr  len_name
# ...

# %%
def inr_con(x):
    return x*80

df['Fare_inr']=df['Fare'].apply(inr_con)

# %%
df.head()
# Out:
#                                                 Name  Unnamed: 0  PassengerId  \
# 0                            Braund, Mr. Owen Harris           0            1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...           1            2
# 2                             Heikkinen, Miss. Laina           2            3
# 3                           Allen, Mr. William Henry           4            5
# 4                                   Moran, Mr. James           5            6
#
#    Survived     Sex   Age  SibSp  Parch            Ticket     Fare Cabin  \
# 0         0    male  22.0      1      0         A/5 21171   7.2500   NaN
# 1         1  female  38.0      1      0          PC 17599  71.2833   C85
# 2         1  female  26.0      0      0  STON/O2. 3101282   7.9250   NaN
# 3         0    male  35.0      0      0            373450   8.0500   NaN
# 4         0    male   NaN      0      0            330877   8.4583   NaN
#
#   Embarked  Fare_inr  len_name
# ...

# %%
def create_flag(x):
    if x<10:
        return "cheap"
    elif x >=10 and  x<20:
        return"mid"
    else:
        return"high"

# %%
df['Fare_inn']=df['Fare'].apply(create_flag)

# %%
df.head()
# Out:
#                                                 Name  Unnamed: 0  PassengerId  \
# 0                            Braund, Mr. Owen Harris           0            1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...           1            2
# 2                             Heikkinen, Miss. Laina           2            3
# 3                           Allen, Mr. William Henry           4            5
# 4                                   Moran, Mr. James           5            6
#
#    Survived     Sex   Age  SibSp  Parch            Ticket     Fare Cabin  \
# 0         0    male  22.0      1      0         A/5 21171   7.2500   NaN
# 1         1  female  38.0      1      0          PC 17599  71.2833   C85
# 2         1  female  26.0      0      0  STON/O2. 3101282   7.9250   NaN
# 3         0    male  35.0      0      0            373450   8.0500   NaN
# 4         0    male   NaN      0      0            330877   8.4583   NaN
#
#   Embarked  Fare_inr  len_name Fare_inn
# ...
