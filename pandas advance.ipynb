# %%
import pandas as pd

# %%
df=pd.read_csv('shopping_trends.csv')

# %%
df.head()
# Out:
#    Customer ID  Age Gender Item Purchased  Category  Purchase Amount (USD)  \
# 0            1   55   Male         Blouse  Clothing                     53
# 1            2   19   Male        Sweater  Clothing                     64
# 2            3   50   Male          Jeans  Clothing                     73
# 3            4   21   Male        Sandals  Footwear                     90
# 4            5   45   Male         Blouse  Clothing                     49
#
#         Location Size      Color  Season  Review Rating Subscription Status  \
# 0       Kentucky    L       Gray  Winter            3.1                 Yes
# 1          Maine    L     Maroon  Winter            3.1                 Yes
# 2  Massachusetts    S     Maroon  Spring            3.1                 Yes
# 3   Rhode Island    M     Maroon  Spring            3.5                 Yes
# 4         Oregon    M  Turquoise  Spring            2.7                 Yes
#
# ...

# %%
df.tail()
# Out:
#       Customer ID  Age  Gender Item Purchased     Category  \
# 3895         3896   40  Female         Hoodie     Clothing
# 3896         3897   52  Female       Backpack  Accessories
# 3897         3898   46  Female           Belt  Accessories
# 3898         3899   44  Female          Shoes     Footwear
# 3899         3900   52  Female        Handbag  Accessories
#
#       Purchase Amount (USD)    Location Size      Color  Season  \
# 3895                     28    Virginia    L  Turquoise  Summer
# 3896                     49        Iowa    L      White  Spring
# 3897                     33  New Jersey    L      Green  Spring
# 3898                     77   Minnesota    S      Brown  Summer
# 3899                     81  California    M      Beige  Spring
#
#       Review Rating Subscription Status Payment Method   Shipping Type  \
# 3895            4.2                  No           Cash  2-Day Shipping
# 3896            4.5                  No         PayPal    Store Pickup
# ...

# %%
df.dtypes
# Out:
# Customer ID                   int64
# Age                           int64
# Gender                       object
# Item Purchased               object
# Category                     object
# Purchase Amount (USD)         int64
# Location                     object
# Size                         object
# Color                        object
# Season                       object
# Review Rating               float64
# Subscription Status          object
# Payment Method               object
# Shipping Type                object
# Discount Applied             object
# Promo Code Used              object
# Previous Purchases            int64
# Preferred Payment Method     object
# Frequency of Purchases       object
# dtype: object

# %%
df.describe()
# Out:
#        Customer ID          Age  Purchase Amount (USD)  Review Rating  \
# count  3900.000000  3900.000000            3900.000000    3900.000000
# mean   1950.500000    44.068462              59.764359       3.749949
# std    1125.977353    15.207589              23.685392       0.716223
# min       1.000000    18.000000              20.000000       2.500000
# 25%     975.750000    31.000000              39.000000       3.100000
# 50%    1950.500000    44.000000              60.000000       3.700000
# 75%    2925.250000    57.000000              81.000000       4.400000
# max    3900.000000    70.000000             100.000000       5.000000
#
#        Previous Purchases
# count         3900.000000
# mean            25.351538
# std             14.447125
# min              1.000000
# 25%             13.000000
# 50%             25.000000
# 75%             38.000000
# max             50.000000

# %%
df.dtypes
# Out:
# Customer ID                   int64
# Age                           int64
# Gender                       object
# Item Purchased               object
# Category                     object
# Purchase Amount (USD)         int64
# Location                     object
# Size                         object
# Color                        object
# Season                       object
# Review Rating               float64
# Subscription Status          object
# Payment Method               object
# Shipping Type                object
# Discount Applied             object
# Promo Code Used              object
# Previous Purchases            int64
# Preferred Payment Method     object
# Frequency of Purchases       object
# dtype: object

# %%
df[['Subscription Status','Preferred Payment Method','Gender']]
# Out:
#      Subscription Status Preferred Payment Method  Gender
# 0                    Yes                    Venmo    Male
# 1                    Yes                     Cash    Male
# 2                    Yes              Credit Card    Male
# 3                    Yes                   PayPal    Male
# 4                    Yes                   PayPal    Male
# ...                  ...                      ...     ...
# 3895                  No                    Venmo  Female
# 3896                  No            Bank Transfer  Female
# 3897                  No                    Venmo  Female
# 3898                  No                    Venmo  Female
# 3899                  No                    Venmo  Female
#
# [3900 rows x 3 columns]

# %%
type(df.dtypes)
# Out:
# pandas.core.series.Series

# %%
df.dtypes=='object'
# Out:
# Customer ID                 False
# Age                         False
# Gender                       True
# Item Purchased               True
# Category                     True
# Purchase Amount (USD)       False
# Location                     True
# Size                         True
# Color                        True
# Season                       True
# Review Rating               False
# Subscription Status          True
# Payment Method               True
# Shipping Type                True
# Discount Applied             True
# Promo Code Used              True
# Previous Purchases          False
# Preferred Payment Method     True
# Frequency of Purchases       True
# dtype: bool

# %%
df.dtypes[df.dtypes=='object'].index
# Out:
# Index(['Gender', 'Item Purchased', 'Category', 'Location', 'Size', 'Color',
#        'Season', 'Subscription Status', 'Payment Method', 'Shipping Type',
#        'Discount Applied', 'Promo Code Used', 'Preferred Payment Method',
#        'Frequency of Purchases'],
#       dtype='object')

# %%
df[df.dtypes[df.dtypes=='object'].index]
# Out:
#       Gender Item Purchased     Category       Location Size      Color  \
# 0       Male         Blouse     Clothing       Kentucky    L       Gray
# 1       Male        Sweater     Clothing          Maine    L     Maroon
# 2       Male          Jeans     Clothing  Massachusetts    S     Maroon
# 3       Male        Sandals     Footwear   Rhode Island    M     Maroon
# 4       Male         Blouse     Clothing         Oregon    M  Turquoise
# ...      ...            ...          ...            ...  ...        ...
# 3895  Female         Hoodie     Clothing       Virginia    L  Turquoise
# 3896  Female       Backpack  Accessories           Iowa    L      White
# 3897  Female           Belt  Accessories     New Jersey    L      Green
# 3898  Female          Shoes     Footwear      Minnesota    S      Brown
# 3899  Female        Handbag  Accessories     California    M      Beige
#
#       Season Subscription Status Payment Method   Shipping Type  \
# ...

# %%
df[df.dtypes[df.dtypes=='object'].index].describe()
# Out:
#        Gender Item Purchased  Category Location  Size  Color  Season  \
# count    3900           3900      3900     3900  3900   3900    3900
# unique      2             25         4       50     4     25       4
# top      Male         Blouse  Clothing  Montana     M  Olive  Spring
# freq     2652            171      1737       96  1755    177     999
#
#        Subscription Status Payment Method  Shipping Type Discount Applied  \
# count                 3900           3900           3900             3900
# unique                   2              6              6                2
# top                     No    Credit Card  Free Shipping               No
# freq                  2847            696            675             2223
#
#        Promo Code Used Preferred Payment Method Frequency of Purchases
# count             3900                     3900                   3900
# unique               2                        6                      7
# ...

# %%
df[df.dtypes[df.dtypes=='int64'].index].describe()
# Out:
#        Customer ID          Age  Purchase Amount (USD)  Previous Purchases
# count  3900.000000  3900.000000            3900.000000         3900.000000
# mean   1950.500000    44.068462              59.764359           25.351538
# std    1125.977353    15.207589              23.685392           14.447125
# min       1.000000    18.000000              20.000000            1.000000
# 25%     975.750000    31.000000              39.000000           13.000000
# 50%    1950.500000    44.000000              60.000000           25.000000
# 75%    2925.250000    57.000000              81.000000           38.000000
# max    3900.000000    70.000000             100.000000           50.000000

# %%
df[df.dtypes[df.dtypes=='float64'].index].describe()
# Out:
#        Review Rating
# count    3900.000000
# mean        3.749949
# std         0.716223
# min         2.500000
# 25%         3.100000
# 50%         3.700000
# 75%         4.400000
# max         5.000000

# %%
df.columns
# Out:
# Index(['Customer ID', 'Age', 'Gender', 'Item Purchased', 'Category',
#        'Purchase Amount (USD)', 'Location', 'Size', 'Color', 'Season',
#        'Review Rating', 'Subscription Status', 'Payment Method',
#        'Shipping Type', 'Discount Applied', 'Promo Code Used',
#        'Previous Purchases', 'Preferred Payment Method',
#        'Frequency of Purchases'],
#       dtype='object')

# %%
df[['Customer ID', 'Age']][4:11]
# Out:
#     Customer ID  Age
# 4             5   45
# 5             6   46
# 6             7   63
# 7             8   27
# 8             9   26
# 9            10   57
# 10           11   53

# %%
df['new']=0

# %%
df
# Out:
#       Customer ID  Age  Gender Item Purchased     Category  \
# 0               1   55    Male         Blouse     Clothing
# 1               2   19    Male        Sweater     Clothing
# 2               3   50    Male          Jeans     Clothing
# 3               4   21    Male        Sandals     Footwear
# 4               5   45    Male         Blouse     Clothing
# ...           ...  ...     ...            ...          ...
# 3895         3896   40  Female         Hoodie     Clothing
# 3896         3897   52  Female       Backpack  Accessories
# 3897         3898   46  Female           Belt  Accessories
# 3898         3899   44  Female          Shoes     Footwear
# 3899         3900   52  Female        Handbag  Accessories
#
#       Purchase Amount (USD)       Location Size      Color  Season  \
# 0                        53       Kentucky    L       Gray  Winter
# 1                        64          Maine    L     Maroon  Winter
# ...

# %%
df['new1']=df['Customer ID']+df['Age']

# %%
df
# Out:
#       Customer ID  Age  Gender Item Purchased     Category  \
# 0               1   55    Male         Blouse     Clothing
# 1               2   19    Male        Sweater     Clothing
# 2               3   50    Male          Jeans     Clothing
# 3               4   21    Male        Sandals     Footwear
# 4               5   45    Male         Blouse     Clothing
# ...           ...  ...     ...            ...          ...
# 3895         3896   40  Female         Hoodie     Clothing
# 3896         3897   52  Female       Backpack  Accessories
# 3897         3898   46  Female           Belt  Accessories
# 3898         3899   44  Female          Shoes     Footwear
# 3899         3900   52  Female        Handbag  Accessories
#
#       Purchase Amount (USD)       Location Size      Color  Season  ...  \
# 0                        53       Kentucky    L       Gray  Winter  ...
# 1                        64          Maine    L     Maroon  Winter  ...
# ...

# %%
pd.Categorical(df['Shipping Type'])
# Out:
# ['Express', 'Express', 'Free Shipping', 'Next Day Air', 'Free Shipping', ..., '2-Day Shipping', 'Store Pickup', 'Standard', 'Express', 'Store Pickup']
# Length: 3900
# Categories (6, object): ['2-Day Shipping', 'Express', 'Free Shipping', 'Next Day Air', 'Standard', 'Store Pickup']

# %%
pd.Categorical(df['Promo Code Used'])
# Out:
# ['Yes', 'Yes', 'Yes', 'Yes', 'Yes', ..., 'No', 'No', 'No', 'No', 'No']
# Length: 3900
# Categories (2, object): ['No', 'Yes']

# %%
pd.Categorical(df['Preferred Payment Method'])
# Out:
# ['Venmo', 'Cash', 'Credit Card', 'PayPal', 'PayPal', ..., 'Venmo', 'Bank Transfer', 'Venmo', 'Venmo', 'Venmo']
# Length: 3900
# Categories (6, object): ['Bank Transfer', 'Cash', 'Credit Card', 'Debit Card', 'PayPal', 'Venmo']

# %%
pd.Categorical(df['Frequency of Purchases']).unique()
# Out:
# ['Fortnightly', 'Weekly', 'Annually', 'Quarterly', 'Bi-Weekly', 'Monthly', 'Every 3 Months']
# Categories (7, object): ['Annually', 'Bi-Weekly', 'Every 3 Months', 'Fortnightly', 'Monthly', 'Quarterly', 'Weekly']

# %%
df[df['Age']>25]
# Out:
#       Customer ID  Age  Gender Item Purchased     Category  \
# 0               1   55    Male         Blouse     Clothing
# 2               3   50    Male          Jeans     Clothing
# 4               5   45    Male         Blouse     Clothing
# 5               6   46    Male       Sneakers     Footwear
# 6               7   63    Male          Shirt     Clothing
# ...           ...  ...     ...            ...          ...
# 3895         3896   40  Female         Hoodie     Clothing
# 3896         3897   52  Female       Backpack  Accessories
# 3897         3898   46  Female           Belt  Accessories
# 3898         3899   44  Female          Shoes     Footwear
# 3899         3900   52  Female        Handbag  Accessories
#
#       Purchase Amount (USD)       Location Size      Color  Season  ...  \
# 0                        53       Kentucky    L       Gray  Winter  ...
# 2                        73  Massachusetts    S     Maroon  Spring  ...
# ...

# %%
len(df)-len(df[df['Age']>25])
# Out:
# 571

# %%
#25.35153

# %%
df[df['Purchase Amount (USD)']<59.764359]
# Out:
#       Customer ID  Age  Gender Item Purchased     Category  \
# 0               1   55    Male         Blouse     Clothing
# 4               5   45    Male         Blouse     Clothing
# 5               6   46    Male       Sneakers     Footwear
# 7               8   27    Male         Shorts     Clothing
# 9              10   57    Male        Handbag  Accessories
# ...           ...  ...     ...            ...          ...
# 3887         3888   40  Female          Shirt     Clothing
# 3891         3892   36  Female          Dress     Clothing
# 3895         3896   40  Female         Hoodie     Clothing
# 3896         3897   52  Female       Backpack  Accessories
# 3897         3898   46  Female           Belt  Accessories
#
#       Purchase Amount (USD)    Location Size      Color  Season  ...  \
# 0                        53    Kentucky    L       Gray  Winter  ...
# 4                        49      Oregon    M  Turquoise  Spring  ...
# ...

# %%
df[df['Purchase Amount (USD)']>59.764359]
# Out:
#       Customer ID  Age  Gender Item Purchased     Category  \
# 1               2   19    Male        Sweater     Clothing
# 2               3   50    Male          Jeans     Clothing
# 3               4   21    Male        Sandals     Footwear
# 6               7   63    Male          Shirt     Clothing
# 8               9   26    Male           Coat    Outerwear
# ...           ...  ...     ...            ...          ...
# 3892         3893   35  Female        Jewelry  Accessories
# 3893         3894   21  Female            Hat  Accessories
# 3894         3895   66  Female          Skirt     Clothing
# 3898         3899   44  Female          Shoes     Footwear
# 3899         3900   52  Female        Handbag  Accessories
#
#       Purchase Amount (USD)       Location Size   Color  Season  ...  \
# 1                        64          Maine    L  Maroon  Winter  ...
# 2                        73  Massachusetts    S  Maroon  Spring  ...
# ...

# %%
df[df['Purchase Amount (USD)']==55]['Customer ID']
# Out:
# 48        49
# 153      154
# 206      207
# 406      407
# 416      417
# 665      666
# 799      800
# 965      966
# 966      967
# 1159    1160
# 1171    1172
# 1193    1194
# 1228    1229
# 1382    1383
# 1501    1502
# 1539    1540
# 1549    1550
# 1756    1757
# 1856    1857
# 2033    2034
# 2165    2166
# 2320    2321
# 2325    2326
# 2408    2409
# 2485    2486
# 2616    2617
# 2867    2868
# 2890    2891
# 2988    2989
# 3013    3014
# 3074    3075
# 3154    3155
# 3271    3272
# 3399    3400
# 3446    3447
# 3544    3545
# 3554    3555
# 3588    3589
# 3699    3700
# 3706    3707
# 3803    3804
# Name: Customer ID, dtype: int64

# %%
df[df['Gender']=='Male']
# Out:
#       Customer ID  Age Gender Item Purchased     Category  \
# 0               1   55   Male         Blouse     Clothing
# 1               2   19   Male        Sweater     Clothing
# 2               3   50   Male          Jeans     Clothing
# 3               4   21   Male        Sandals     Footwear
# 4               5   45   Male         Blouse     Clothing
# ...           ...  ...    ...            ...          ...
# 2647         2648   60   Male          Shoes     Footwear
# 2648         2649   51   Male          Pants     Clothing
# 2649         2650   23   Male         Gloves  Accessories
# 2650         2651   20   Male          Socks     Clothing
# 2651         2652   51   Male       Sneakers     Footwear
#
#       Purchase Amount (USD)        Location Size      Color  Season  ...  \
# 0                        53        Kentucky    L       Gray  Winter  ...
# 1                        64           Maine    L     Maroon  Winter  ...
# ...

# %%
df[df['Gender']=='Female']
# Out:
#       Customer ID  Age  Gender Item Purchased     Category  \
# 2652         2653   23  Female         Shorts     Clothing
# 2653         2654   67  Female         Blouse     Clothing
# 2654         2655   23  Female           Coat    Outerwear
# 2655         2656   26  Female     Sunglasses  Accessories
# 2656         2657   52  Female         Shorts     Clothing
# ...           ...  ...     ...            ...          ...
# 3895         3896   40  Female         Hoodie     Clothing
# 3896         3897   52  Female       Backpack  Accessories
# 3897         3898   46  Female           Belt  Accessories
# 3898         3899   44  Female          Shoes     Footwear
# 3899         3900   52  Female        Handbag  Accessories
#
#       Purchase Amount (USD)    Location Size      Color  Season  ...  \
# 2652                     20    Maryland    L       Cyan  Summer  ...
# 2653                     36   Wisconsin    L   Lavender    Fall  ...
# ...

# %%
df.head(4)
# Out:
#    Customer ID  Age Gender Item Purchased  Category  Purchase Amount (USD)  \
# 0            1   55   Male         Blouse  Clothing                     53
# 1            2   19   Male        Sweater  Clothing                     64
# 2            3   50   Male          Jeans  Clothing                     73
# 3            4   21   Male        Sandals  Footwear                     90
#
#         Location Size   Color  Season  ...  Subscription Status  \
# 0       Kentucky    L    Gray  Winter  ...                  Yes
# 1          Maine    L  Maroon  Winter  ...                  Yes
# 2  Massachusetts    S  Maroon  Spring  ...                  Yes
# 3   Rhode Island    M  Maroon  Spring  ...                  Yes
#
#   Payment Method  Shipping Type Discount Applied Promo Code Used  \
# 0    Credit Card        Express              Yes             Yes
# 1  Bank Transfer        Express              Yes             Yes
# 2           Cash  Free Shipping              Yes             Yes
# ...

# %%
df['Gender']=='Female'
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 3895     True
# 3896     True
# 3897     True
# 3898     True
# 3899     True
# Name: Gender, Length: 3900, dtype: bool

# %%
df['Purchase Amount (USD)']>73
# Out:
# 0       False
# 1       False
# 2       False
# 3        True
# 4       False
#         ...
# 3895    False
# 3896    False
# 3897    False
# 3898     True
# 3899     True
# Name: Purchase Amount (USD), Length: 3900, dtype: bool

# %%
df[(df['Gender']=='Female') & (df['Purchase Amount (USD)']>73 )]
# Out:
#       Customer ID  Age  Gender Item Purchased     Category  \
# 2655         2656   26  Female     Sunglasses  Accessories
# 2656         2657   52  Female         Shorts     Clothing
# 2657         2658   52  Female          Dress     Clothing
# 2660         2661   24  Female          Pants     Clothing
# 2661         2662   43  Female          Boots     Footwear
# ...           ...  ...     ...            ...          ...
# 3890         3891   35  Female          Shirt     Clothing
# 3892         3893   35  Female        Jewelry  Accessories
# 3894         3895   66  Female          Skirt     Clothing
# 3898         3899   44  Female          Shoes     Footwear
# 3899         3900   52  Female        Handbag  Accessories
#
#       Purchase Amount (USD)        Location Size   Color  Season  ...  \
# 2655                     83         Wyoming    M    Gray  Summer  ...
# 2656                     76         Indiana    L  Yellow  Winter  ...
# ...

# %%
df[(df['Gender']=='Male') & (df['Purchase Amount (USD)']>73 )]
# Out:
#       Customer ID  Age Gender Item Purchased     Category  \
# 3               4   21   Male        Sandals     Footwear
# 6               7   63   Male          Shirt     Clothing
# 8               9   26   Male           Coat    Outerwear
# 15             16   64   Male          Skirt     Clothing
# 19             20   66   Male          Pants     Clothing
# ...           ...  ...    ...            ...          ...
# 2640         2641   30   Male          Skirt     Clothing
# 2642         2643   39   Male           Belt  Accessories
# 2644         2645   25   Male          Pants     Clothing
# 2645         2646   23   Male          Scarf  Accessories
# 2648         2649   51   Male          Pants     Clothing
#
#       Purchase Amount (USD)       Location Size      Color  Season  ...  \
# 3                        90   Rhode Island    M     Maroon  Spring  ...
# 6                        85        Montana    M       Gray    Fall  ...
# ...

# %%
df[(df['Gender']=='Female') | (df['Purchase Amount (USD)']>73 )]
# Out:
#       Customer ID  Age  Gender Item Purchased     Category  \
# 3               4   21    Male        Sandals     Footwear
# 6               7   63    Male          Shirt     Clothing
# 8               9   26    Male           Coat    Outerwear
# 15             16   64    Male          Skirt     Clothing
# 19             20   66    Male          Pants     Clothing
# ...           ...  ...     ...            ...          ...
# 3895         3896   40  Female         Hoodie     Clothing
# 3896         3897   52  Female       Backpack  Accessories
# 3897         3898   46  Female           Belt  Accessories
# 3898         3899   44  Female          Shoes     Footwear
# 3899         3900   52  Female        Handbag  Accessories
#
#       Purchase Amount (USD)       Location Size      Color  Season  ...  \
# 3                        90   Rhode Island    M     Maroon  Spring  ...
# 6                        85        Montana    M       Gray    Fall  ...
# ...

# %%
df.head(4)
# Out:
#    Customer ID  Age Gender Item Purchased  Category  Purchase Amount (USD)  \
# 0            1   55   Male         Blouse  Clothing                     53
# 1            2   19   Male        Sweater  Clothing                     64
# 2            3   50   Male          Jeans  Clothing                     73
# 3            4   21   Male        Sandals  Footwear                     90
#
#         Location Size   Color  Season  ...  Subscription Status  \
# 0       Kentucky    L    Gray  Winter  ...                  Yes
# 1          Maine    L  Maroon  Winter  ...                  Yes
# 2  Massachusetts    S  Maroon  Spring  ...                  Yes
# 3   Rhode Island    M  Maroon  Spring  ...                  Yes
#
#   Payment Method  Shipping Type Discount Applied Promo Code Used  \
# 0    Credit Card        Express              Yes             Yes
# 1  Bank Transfer        Express              Yes             Yes
# 2           Cash  Free Shipping              Yes             Yes
# ...

# %%
max(df['Purchase Amount (USD)'])
# Out:
# 100

# %%
df[df['Purchase Amount (USD)']==max(df['Purchase Amount (USD)'])]
# Out:
#       Customer ID  Age  Gender Item Purchased     Category  \
# 42             43   20    Male           Coat    Outerwear
# 95             96   37    Male       Sneakers     Footwear
# 193           194   36    Male           Belt  Accessories
# 204           205   24    Male       Sneakers     Footwear
# 243           244   25    Male        Jewelry  Accessories
# 248           249   47    Male           Belt  Accessories
# 455           456   54    Male         Blouse     Clothing
# 518           519   24    Male         Blouse     Clothing
# 581           582   32    Male        Sweater     Clothing
# 615           616   67    Male        Sandals     Footwear
# 769           770   52    Male          Socks     Clothing
# 861           862   46    Male          Skirt     Clothing
# 1208         1209   20    Male          Boots     Footwear
# 1300         1301   67    Male        T-shirt     Clothing
# 1405         1406   33    Male          Socks     Clothing
# ...

# %%
df[0:100:2]
# Out:
#     Customer ID  Age Gender Item Purchased     Category  \
# 0             1   55   Male         Blouse     Clothing
# 2             3   50   Male          Jeans     Clothing
# 4             5   45   Male         Blouse     Clothing
# 6             7   63   Male          Shirt     Clothing
# 8             9   26   Male           Coat    Outerwear
# 10           11   53   Male          Shoes     Footwear
# 12           13   61   Male           Coat    Outerwear
# 14           15   64   Male           Coat    Outerwear
# 16           17   25   Male     Sunglasses  Accessories
# 18           19   52   Male        Sweater     Clothing
# 20           21   21   Male          Pants     Clothing
# 22           23   56   Male          Pants     Clothing
# 24           25   18   Male         Jacket    Outerwear
# 26           27   38   Male        Jewelry  Accessories
# 28           29   54   Male        Handbag  Accessories
# 30           31   57   Male        Jewelry  Accessories
# ...

# %%
df.head(2)
# Out:
#    Customer ID  Age Gender Item Purchased  Category  Purchase Amount (USD)  \
# 0            1   55   Male         Blouse  Clothing                     53
# 1            2   19   Male        Sweater  Clothing                     64
#
#    Location Size   Color  Season  ...  Subscription Status Payment Method  \
# 0  Kentucky    L    Gray  Winter  ...                  Yes    Credit Card
# 1     Maine    L  Maroon  Winter  ...                  Yes  Bank Transfer
#
#   Shipping Type Discount Applied Promo Code Used Previous Purchases  \
# 0       Express              Yes             Yes                 14
# 1       Express              Yes             Yes                  2
#
#    Preferred Payment Method Frequency of Purchases new  new1
# 0                     Venmo            Fortnightly   0    56
# 1                      Cash            Fortnightly   0    21
#
# [2 rows x 21 columns]

# %%
df.iloc[0:2]
# Out:
#    Customer ID  Age Gender Item Purchased  Category  Purchase Amount (USD)  \
# 0            1   55   Male         Blouse  Clothing                     53
# 1            2   19   Male        Sweater  Clothing                     64
#
#    Location Size   Color  Season  ...  Subscription Status Payment Method  \
# 0  Kentucky    L    Gray  Winter  ...                  Yes    Credit Card
# 1     Maine    L  Maroon  Winter  ...                  Yes  Bank Transfer
#
#   Shipping Type Discount Applied Promo Code Used Previous Purchases  \
# 0       Express              Yes             Yes                 14
# 1       Express              Yes             Yes                  2
#
#    Preferred Payment Method Frequency of Purchases new  new1
# 0                     Venmo            Fortnightly   0    56
# 1                      Cash            Fortnightly   0    21
#
# [2 rows x 21 columns]

# %%
df.loc[0:2]
# Out:
#    Customer ID  Age Gender Item Purchased  Category  Purchase Amount (USD)  \
# 0            1   55   Male         Blouse  Clothing                     53
# 1            2   19   Male        Sweater  Clothing                     64
# 2            3   50   Male          Jeans  Clothing                     73
#
#         Location Size   Color  Season  ...  Subscription Status  \
# 0       Kentucky    L    Gray  Winter  ...                  Yes
# 1          Maine    L  Maroon  Winter  ...                  Yes
# 2  Massachusetts    S  Maroon  Spring  ...                  Yes
#
#   Payment Method  Shipping Type Discount Applied Promo Code Used  \
# 0    Credit Card        Express              Yes             Yes
# 1  Bank Transfer        Express              Yes             Yes
# 2           Cash  Free Shipping              Yes             Yes
#
#   Previous Purchases  Preferred Payment Method Frequency of Purchases new  \
# ...

# %%
df.iloc[0:2:,[0,1,2]]
# Out:
#    Customer ID  Age Gender
# 0            1   55   Male
# 1            2   19   Male

# %%
df.loc[0:2:,['Customer ID','Age','Gender']]
# Out:
#    Customer ID  Age Gender
# 0            1   55   Male
# 1            2   19   Male
# 2            3   50   Male
